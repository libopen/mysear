# %%
# %matplotlib inline
import pandas as pd
df=(pd.read_csv('/home/libin/data/index_day.csv',parse_dates=[0],keep_date_col=True,index_col=['date'])
      .drop(['f1','f2','f3','f4','ftotal'],axis=1)
      .sort_index()
    ) 

df[df.index>'2017-7-1'].plot(subplots=True,figsize=(20,5))
df[df.index>'2017-7-1'].plot(kind='bar',figsize=(20,5))
