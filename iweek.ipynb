# %%
# %matplotlib inline
import pandas as pd
df=(pd.read_csv('/home/libin/data/index_week.csv')
      .drop(['f1','f2','f3','f4','ftotal'],axis=1)
      .assign(date=lambda x :pd.to_datetime(x['date']))
      .set_index('date')
      .sort_index()
    )
df[df.index>'2016-1-1'].plot(figsize=(20,5),kind='bar')
df[df.index>'2016-1-1'].plot(subplots=True,figsize=(20,5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x2aaabd8b1a20>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2aaabb9c2668>], dtype=object)
